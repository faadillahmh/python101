# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)]
}

df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          462                 46
# 1        UAS1         Fisika                          619                 83
# 2        UTS2         Fisika                          437                 72
# 3        UAS2         Fisika                          326                 75
# 4        UTS1     Matematika                          784                 62
# 5        UAS1     Matematika                          233                 58
# 6        UTS2     Matematika                          536                 77
# 7        UAS2     Matematika                          609                 80
# 8        UTS1     Statistika                          391                 70
# 9        UAS1     Statistika                          698                 69
# 10       UTS2     Statistika                          500                 61
# 11       UAS2     Statistika                          248                 57

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Soal 1. Data Cleaning
#
# Lakukan sorting data berdasarkan Rata2 nilai ujian dari terbesar ke terkecil
#
# *   Lakukan sorting data berdasarkan Rata2 nilai ujian dari terbesar ke terkecil
# *   Tipe Ujian dan Mata pelajaran apakah yang memiliki rata2 nilai terkecil?

# %%
#code here
# Lakukan sorting data berdasarkan Rata2 nilai ujian
# dari terbesar ke terkecil

df.sort_values('Rata2 Nilai Ujian', ascending=False)
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 1        UAS1         Fisika                          619                 83
# 7        UAS2     Matematika                          609                 80
# 6        UTS2     Matematika                          536                 77
# 3        UAS2         Fisika                          326                 75
# 2        UTS2         Fisika                          437                 72
# 8        UTS1     Statistika                          391                 70
# 9        UAS1     Statistika                          698                 69
# 4        UTS1     Matematika                          784                 62
# 10       UTS2     Statistika                          500                 61
# 5        UAS1     Matematika                          233                 58
# 11       UAS2     Statistika                          248                 57
# 0        UTS1         Fisika                          462                 46

# %% [markdown]
# Tipe Ujian dan Mata pelajaran yang memiliki rata2 nilai terkecil adalah UTS1 Fisika dengan rata2 nilai 46.

# %% [markdown]
# Expected output:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=1iv8P-LDdN3WpTVX9qST3kL7QSNSDiOc2)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# <h2>Soal 2: Data Restructuring</h2>
#
# Jelaskan apa itu pivoting dan melting data

# %% [markdown]
# Pivoting adalah pengubahan bentuk data dengan mengganti data yang terletak di baris menjadi di kolom.
#
# Sedangkan Melting adalah kebalikan dari Pivoting, yaitu pengubahan bentuk data dengan mengganti data yang terletak di kolom menjadi di baris.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# <h2>Soal 3: Reshaping Data 1</h2>

# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)]
}

df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          717                 67
# 1        UAS1         Fisika                          280                 56
# 2        UTS2         Fisika                          626                 81
# 3        UAS2         Fisika                          678                 89
# 4        UTS1     Matematika                          345                 79
# 5        UAS1     Matematika                          570                 92
# 6        UTS2     Matematika                          772                 62
# 7        UAS2     Matematika                          237                 56
# 8        UTS1     Statistika                          514                 90
# 9        UAS1     Statistika                          498                 81
# 10       UTS2     Statistika                          537                 76
# 11       UAS2     Statistika                          602                 80

# %% [markdown]
# Perhatikan data di atas, kemudian ubahlah bentuknya agar sesuai yang di harapkan.

# %%
#code here
pivot = df.pivot_table(index = 'Tipe Ujian', columns='Mata Pelajaran', values=['Rata2 Nilai Ujian', 'Rata2 Waktu Belajar (menit)'])
pivot
# Out:
#                Rata2 Nilai Ujian                        \
# Mata Pelajaran            Fisika Matematika Statistika
# Tipe Ujian
# UAS1                          56         92         81
# UAS2                          89         56         80
# UTS1                          67         79         90
# UTS2                          81         62         76
#
#                Rata2 Waktu Belajar (menit)
# Mata Pelajaran                      Fisika Matematika Statistika
# Tipe Ujian
# UAS1                                   280        570        498
# UAS2                                   678        237        602
# UTS1                                   717        345        514
# UTS2                                   626        772        537

# %% [markdown]
# Expected Result:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=1XufsfqZe7-XZLsb92SpATexy-QRZE0ow)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# <h2>Soal 4: Reshaping Data 2</h2>

# %%
import pandas as pd

data = {
    'Hari' : ['Sabtu', 'Minggu'],
    'Kebun Binatang' : [271, 399],
    'Dufan' : [501, 700],
    'Disney' : [1000, 1001],
    'Bali' : [900, 803]
}
df = pd.DataFrame(data).set_index('Hari')
df
# Out:
#         Kebun Binatang  Dufan  Disney  Bali
# Hari
# Sabtu              271    501    1000   900
# Minggu             399    700    1001   803

# %% [markdown]
# diatas adalah data tentang jumlah pengunjung di berbagai tempat hiburan, ubahlah struktur data tersebut sehingga sesuai dengan hasil yang diharapkan.

# %%
#code here
# saya izin mengembalikan 'Hari' menjadi value (tidak menjadi index lagi)
df = pd.DataFrame(data)

melt = df.melt()
melt
# Out:
#          variable   value
# 0            Hari   Sabtu
# 1            Hari  Minggu
# 2  Kebun Binatang     271
# 3  Kebun Binatang     399
# 4           Dufan     501
# 5           Dufan     700
# 6          Disney    1000
# 7          Disney    1001
# 8            Bali     900
# 9            Bali     803

# %%
melt = df.melt(id_vars='Hari', var_name='Tempat Hiburan', value_name='Pengunjung')
melt
# Out:
#      Hari  Tempat Hiburan  Pengunjung
# 0   Sabtu  Kebun Binatang         271
# 1  Minggu  Kebun Binatang         399
# 2   Sabtu           Dufan         501
# 3  Minggu           Dufan         700
# 4   Sabtu          Disney        1000
# 5  Minggu          Disney        1001
# 6   Sabtu            Bali         900
# 7  Minggu            Bali         803

# %% [markdown]
# Expected Result:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=159mIqcyfeD30EEcyZmmkovORa6cZDLtn)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# <h2>Soal 5: Data Enrichment</h2>
#
# Lakukan binning data menggunakan qcut sehingga sesuai hasil yang diharapkan

# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)]
}

df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          734                 93
# 1        UAS1         Fisika                          719                 42
# 2        UTS2         Fisika                          474                 92
# 3        UAS2         Fisika                          748                 49
# 4        UTS1     Matematika                          752                 85
# 5        UAS1     Matematika                          451                 95
# 6        UTS2     Matematika                          752                 81
# 7        UAS2     Matematika                          405                 91
# 8        UTS1     Statistika                          788                 64
# 9        UAS1     Statistika                          367                 87
# 10       UTS2     Statistika                          521                 65
# 11       UAS2     Statistika                          572                 95

# %%
#code here
pd.qcut(df['Rata2 Nilai Ujian'], q=3)
# Out:
# 0       (91.333, 95.0]
# 1     (41.999, 75.667]
# 2       (91.333, 95.0]
# 3     (41.999, 75.667]
# 4     (75.667, 91.333]
# 5       (91.333, 95.0]
# 6     (75.667, 91.333]
# 7     (75.667, 91.333]
# 8     (41.999, 75.667]
# 9     (75.667, 91.333]
# 10    (41.999, 75.667]
# 11      (91.333, 95.0]
# Name: Rata2 Nilai Ujian, dtype: category
# Categories (3, interval[float64, right]): [(41.999, 75.667] < (75.667, 91.333] < (91.333, 95.0]]

# %%
label = ['tidak lulus', 'remedial', 'lulus']
keterangan = pd.qcut(df['Rata2 Nilai Ujian'], q=3, labels=label)
df['Keterangan Kelulusan'] = keterangan
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian  \
# 0        UTS1         Fisika                          734                 93
# 1        UAS1         Fisika                          719                 42
# 2        UTS2         Fisika                          474                 92
# 3        UAS2         Fisika                          748                 49
# 4        UTS1     Matematika                          752                 85
# 5        UAS1     Matematika                          451                 95
# 6        UTS2     Matematika                          752                 81
# 7        UAS2     Matematika                          405                 91
# 8        UTS1     Statistika                          788                 64
# 9        UAS1     Statistika                          367                 87
# 10       UTS2     Statistika                          521                 65
# 11       UAS2     Statistika                          572                 95
#
#    Keterangan Kelulusan
# 0                 lulus
# 1           tidak lulus
# 2                 lulus
# 3           tidak lulus
# 4              remedial
# 5                 lulus
# 6              remedial
# 7              remedial
# 8           tidak lulus
# 9              remedial
# 10          tidak lulus
# 11                lulus

# %% [markdown]
# Expected Output:
#
# (Output bisa berbeda-beda)
#
# ![alt text](https://drive.google.com/uc?id=1h2_u5_xhD1_QtPpItTj-o3lljHhnr4XS)

# %% [markdown]
# ---
#
#
#
# ---
