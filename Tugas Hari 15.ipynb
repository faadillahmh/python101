# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# # Soal 1: Scatter Plot

# %% [markdown]
# Buatlah scatterplot menggunakan Seaborn dari data df di atas, variasikan menggunakan palette yang telah disediakan sehingga didapatkan output sesuai expected.

# %%
interval=df['interval']=pd.qcut(df['depth'], q=6)
interval
# Out:
# 0          (61.4, 61.8]
# 1        (42.999, 60.6]
# 2        (42.999, 60.6]
# 3          (62.3, 62.9]
# 4          (62.9, 79.0]
#               ...
# 53935      (60.6, 61.4]
# 53936      (62.9, 79.0]
# 53937      (62.3, 62.9]
# 53938      (60.6, 61.4]
# 53939      (61.8, 62.3]
# Name: depth, Length: 53940, dtype: category
# Categories (6, interval[float64, right]): [(42.999, 60.6] < (60.6, 61.4] < (61.4, 61.8] <
#                                            (61.8, 62.3] < (62.3, 62.9] < (62.9, 79.0]]

# %%
sns.set({'figure.figsize':(13,13)})
palette = "ch:r=-.2,d=.3_r"

#code here
bins = [42.9, 60.6, 61.4, 61.8, 62.3, 62.9, 79.0]
order = ['48', '54', '60', '66', '72','78']
df['depth_'] = pd.cut(df['depth'], bins=bins, labels=order)

sns.scatterplot(data=df, x='carat', y='price', hue='clarity', style='depth_', palette = "ch:r=-.2,d=.3_r", style_order=order, size='depth_', sizes=(30, 10), markers='o')
# Out:
# <ipython-input-52-c0b0ddf1a490>:9: UserWarning:
# The markers list has fewer values (1) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df, x='carat', y='price', hue='clarity', style='depth_', palette = "ch:r=-.2,d=.3_r", style_order=order, size='depth_', sizes=(30, 10), markers='o')
# <Axes: xlabel='carat', ylabel='price'>

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1JLtkSpx0TfSF7fMSBcZuXaY_tNkR5LYc)

# %% [markdown]
# # Soal 2: Catplot

# %% [markdown]
# Buatlah sebuah Categorical plot dengan kind = 'boxplot', sehingga diperoleh hasil seperti expected output berikut:

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#          interval depth_orde depth_
# 0    (61.4, 61.8]         60     60
# 1  (42.999, 60.6]         48     48
# 2  (42.999, 60.6]         48     48
# 3    (62.3, 62.9]         72     72
# 4    (62.9, 79.0]         78     78

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 6), sharey=True)

cuts = df['cut'].unique()

for ax, cut in zip(axes, cuts):
    sns.boxplot(x='clarity', y='price', data=df[df['cut'] == cut], palette='Set2', ax=ax)
    ax.set_title(f'Cut = {cut}')
    ax.set_xlabel('Clarity')
    ax.set_ylabel('Price')
    ax.set_ylim

plt.tight_layout()

plt.show()
# Out:
# <ipython-input-106-9e58a39d7c4e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='clarity', y='price', data=df[df['cut'] == cut], palette='Set2', ax=ax)
# <ipython-input-106-9e58a39d7c4e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='clarity', y='price', data=df[df['cut'] == cut], palette='Set2', ax=ax)
# <ipython-input-106-9e58a39d7c4e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='clarity', y='price', data=df[df['cut'] == cut], palette='Set2', ax=ax)
# <ipython-input-106-9e58a39d7c4e>:6: FutureWarning:
#
# ...

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=17mSiL-qQtFB2D8rUYB0v7d6tOrOHDoh6)

# %% [markdown]
# # Soal 3: Pair Plot

# %% [markdown]
# Ambil 300 data secara acak dari df, kemudian buat pair plotnya dari 300 data tersebut untuk kolom carat, depth, table, dan price serta markers =  ['p', 'o', 's', 'D', 'X'] sehingga dihasilkan output sesuai expected.

# %%
df = df.sample(n=300, random_state=123)

#code here

markers = ['p', 'o', 's', 'D', 'X']
g = sns.pairplot(df, vars=['carat', 'depth', 'table', 'price'], hue='cut', markers=markers)
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=12rStINwUNGpqZd1iIGaqzTIvw9irAkJ0)

# %% [markdown]
# # Soal 4: Joint Plot

# %% [markdown]
# Gunakan data yang sama dengan soal 3 untuk menghasilkan dua visualisasi joint plot antara carat dan price nya sesuai expected output.

# %%
#code here
with sns.axes_style('white'):
  sns.jointplot(x='carat', y='price', kind='kde', data=df)

sns.jointplot(x='carat', y='price', data=df, kind='reg')

# %% [markdown]
# Expected Output 1:
#
# ![alt text](https://drive.google.com/uc?id=17MY9L4bUSxuCIRxDl7Ey34_RrfXjlcim)
#
# Expected Output 2:
#
# ![alt text](https://drive.google.com/uc?id=1A5vQ66KLZ9sbJ_qDoAkuAF3Z213ricZW)
